# %%
# Import Library
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from datetime import datetime

# %%
# Import excel file containing series id, url list, and title (retrieved from sitemap of the main url)
df = pd.read_excel(r"~/Documents/Datasets/kakao/kakao_webtoon.xlsx")
df.head()
# Out:
#    Id                                            Content  \
# 0   1    https://id.kakaowebtoon.com/content/Dr.-Brain/1
# 1   2  https://id.kakaowebtoon.com/content/The-Tyrant...
# 2   3  https://id.kakaowebtoon.com/content/Starting-f...
# 3   4  https://id.kakaowebtoon.com/content/My-Life-as...
# 4   5  https://id.kakaowebtoon.com/content/Go-Youngsi...
#
#                            Title_Ori
# 0                          Dr. Brain
# 1          The Tyrant's Tranquilizer
# 2  Starting from Today Im a Princess
# 3                My Life as a Player
# 4          Go Youngsins Trainee Life

# %%
# Create empty list to store loop result containing list of all columns
by_titles = []
n = len(df["Content"])

# %%
# Iterate for all series in the list
for i in range(n):
    try:
        the_url = df.loc[i, "Content"]
        the_id = df.loc[i, "Id"]

        result = requests.get(the_url)

        soup = BeautifulSoup(result.content, 'html5lib')

        subresults = soup.find_all("p")
        subresult_text = [subresult.text for subresult in subresults if subresult.text and subresult.text != "0"]

        by_title = {'Id': the_id,
                    'subresult_text': subresult_text[:],
                    'title': subresult_text[0],
                    'author_group': subresult_text[1],
                    'genre': subresult_text[2],
                    'views': subresult_text[3],
                    'likes': subresult_text[4],
                    'desc': soup.find("meta", attrs={'name': 'description'})["content"]}

        by_titles.append(by_title)
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for iteration {i}: {e}")
        break
    except (KeyError, IndexError) as e:
        print(f"Error parsing data for iteration {i}: {e}")
        break

# %%
len(by_titles)
# Out:
# 628

# %%
n
# Out:
# 628

# %%
# Transform dictionary to dataframe
df_detail = pd.DataFrame.from_dict(by_titles)
df_detail.tail()
# Out:
#       Id                                     subresult_text  \
# 623  642  [The Beloved Fake Saint, jn, financier, Junye,...
# 624  643  [Dealing with the Secretive Male Second-Lead, ...
# 625  644  [One Night Relationship, ZUOAN KAMAN, Romansa,...
# 626  646  [Adeline's Deep Night, MUA, HAPSTER,CHEEZENAAN...
# 627  648  [Royal Marriage, HIYA, Kangryeol, Portofino​, ...
#
#                                            title  \
# 623                       The Beloved Fake Saint
# 624  Dealing with the Secretive Male Second-Lead
# 625                       One Night Relationship
# 626                         Adeline's Deep Night
# 627                               Royal Marriage
#
#                                author_group            genre   views   likes  \
# 623                    jn, financier, Junye  Romansa Fantasi    2,2M  590,1K
# 624             Insulaire, samo, Lee sinrok  Romansa Fantasi    999K  284,3K
# 625                             ZUOAN KAMAN          Romansa  356,7K   40,9K
# 626  MUA, HAPSTER,CHEEZENAAN, Lee hyeonsung  Romansa Fantasi    1,5M  360,5K
# 627             HIYA, Kangryeol, Portofino​  Romansa Fantasi    1,7M  408,8K
#
#                                                   desc
# 623  Aku menjadi seorang Saintess palsu dalam sebua...
# 624  Saat menghadiri pesta tahun baru bersama tunan...
# 625  Gara-gara dua kejadian yang terjadi dalam satu...
# 626  Di malam yang gelap dan dingin, Adeline dibunu...
# 627  Tatiana Cartienne, wanita dengan kekayaan dan ...

# %%
# Create column storing the number of authors involved (n_author_group) from counting elements in "author_group"
df_detail['n_author_group'] = df_detail['author_group'].str.count(",")+1
df_detail.tail()
# Out:
#       Id                                     subresult_text  \
# 623  642  [The Beloved Fake Saint, jn, financier, Junye,...
# 624  643  [Dealing with the Secretive Male Second-Lead, ...
# 625  644  [One Night Relationship, ZUOAN KAMAN, Romansa,...
# 626  646  [Adeline's Deep Night, MUA, HAPSTER,CHEEZENAAN...
# 627  648  [Royal Marriage, HIYA, Kangryeol, Portofino​, ...
#
#                                            title  \
# 623                       The Beloved Fake Saint
# 624  Dealing with the Secretive Male Second-Lead
# 625                       One Night Relationship
# 626                         Adeline's Deep Night
# 627                               Royal Marriage
#
#                                author_group            genre   views   likes  \
# 623                    jn, financier, Junye  Romansa Fantasi    2,2M  590,1K
# 624             Insulaire, samo, Lee sinrok  Romansa Fantasi    999K  284,3K
# 625                             ZUOAN KAMAN          Romansa  356,7K   40,9K
# 626  MUA, HAPSTER,CHEEZENAAN, Lee hyeonsung  Romansa Fantasi    1,5M  360,5K
# 627             HIYA, Kangryeol, Portofino​  Romansa Fantasi    1,7M  408,8K
#
#                                                   desc  n_author_group
# 623  Aku menjadi seorang Saintess palsu dalam sebua...               3
# 624  Saat menghadiri pesta tahun baru bersama tunan...               3
# 625  Gara-gara dua kejadian yang terjadi dalam satu...               1
# 626  Di malam yang gelap dan dingin, Adeline dibunu...               4
# 627  Tatiana Cartienne, wanita dengan kekayaan dan ...               3

# %%
df_main = df_detail.drop(columns = ["subresult_text"])
df_main.tail()
# Out:
#       Id                                        title  \
# 623  642                       The Beloved Fake Saint
# 624  643  Dealing with the Secretive Male Second-Lead
# 625  644                       One Night Relationship
# 626  646                         Adeline's Deep Night
# 627  648                               Royal Marriage
#
#                                author_group            genre   views   likes  \
# 623                    jn, financier, Junye  Romansa Fantasi    2,2M  590,1K
# 624             Insulaire, samo, Lee sinrok  Romansa Fantasi    999K  284,3K
# 625                             ZUOAN KAMAN          Romansa  356,7K   40,9K
# 626  MUA, HAPSTER,CHEEZENAAN, Lee hyeonsung  Romansa Fantasi    1,5M  360,5K
# 627             HIYA, Kangryeol, Portofino​  Romansa Fantasi    1,7M  408,8K
#
#                                                   desc  n_author_group
# 623  Aku menjadi seorang Saintess palsu dalam sebua...               3
# 624  Saat menghadiri pesta tahun baru bersama tunan...               3
# 625  Gara-gara dua kejadian yang terjadi dalam satu...               1
# 626  Di malam yang gelap dan dingin, Adeline dibunu...               4
# 627  Tatiana Cartienne, wanita dengan kekayaan dan ...               3

# %%
df_main.dtypes
# Out:
# Id                 int64
# title             object
# author_group      object
# genre             object
# views             object
# likes             object
# desc              object
# n_author_group     int64
# dtype: object

# %%
# Numbers in views and likes (1,7M/999K) are stored as string - to transform
def string_to_num(text):
    if "K" in text:
        return int(float(text.split("K")[0])*1000)
    elif "M" in text:
        return int(float(text.split("M")[0])*1000000)
    else:
        return int(text)

# %%
df_main["views"] = df_main["views"].str.replace(",",".").apply(string_to_num)
df_main["likes"] = df_main["likes"].str.replace(",",".").apply(string_to_num)
df_main.tail()
# Out:
#       Id                                        title  \
# 623  642                       The Beloved Fake Saint
# 624  643  Dealing with the Secretive Male Second-Lead
# 625  644                       One Night Relationship
# 626  646                         Adeline's Deep Night
# 627  648                               Royal Marriage
#
#                                author_group            genre    views   likes  \
# 623                    jn, financier, Junye  Romansa Fantasi  2200000  590100
# 624             Insulaire, samo, Lee sinrok  Romansa Fantasi   999000  284300
# 625                             ZUOAN KAMAN          Romansa   356700   40900
# 626  MUA, HAPSTER,CHEEZENAAN, Lee hyeonsung  Romansa Fantasi  1500000  360500
# 627             HIYA, Kangryeol, Portofino​  Romansa Fantasi  1700000  408800
#
#                                                   desc  n_author_group
# 623  Aku menjadi seorang Saintess palsu dalam sebua...               3
# 624  Saat menghadiri pesta tahun baru bersama tunan...               3
# 625  Gara-gara dua kejadian yang terjadi dalam satu...               1
# 626  Di malam yang gelap dan dingin, Adeline dibunu...               4
# 627  Tatiana Cartienne, wanita dengan kekayaan dan ...               3

# %%
# Replace "genre" to english
df_main["genre"] = df_main["genre"].replace(["Romansa Fantasi", "Romansa", "Aksi"],["Romance Fantasy", "Romance", "Action"])
df_main["genre"].value_counts()
# Out:
# Romance Fantasy    313
# Romance            186
# Action              71
# Drama               58
# Name: genre, dtype: int64

# %%
df_main.to_excel(r"~/Documents/kakao_dataset.xlsx")
